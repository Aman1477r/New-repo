# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman1477r/New-repo/blob/main/mlday1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import resample

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age_mean'] = df['age'].fillna(df['age'].mean())

# %% [markdown]
# #  mean method

# %%
df[['age_mean','age']]
# Out:
#       age_mean   age
# 0    22.000000  22.0
# 1    38.000000  38.0
# 2    26.000000  26.0
# 3    35.000000  35.0
# 4    35.000000  35.0
# ..         ...   ...
# 886  27.000000  27.0
# 887  19.000000  19.0
# 888  29.699118   NaN
# 889  26.000000  26.0
# 890  32.000000  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# 2 meadian method

# %%
df['age_median'] = df['age'].fillna(df['age'].median())

# %%
df[['age_median','age']]
# Out:
#      age_median   age
# 0          22.0  22.0
# 1          38.0  38.0
# 2          26.0  26.0
# 3          35.0  35.0
# 4          35.0  35.0
# ..          ...   ...
# 886        27.0  27.0
# 887        19.0  19.0
# 888        28.0   NaN
# 889        26.0  26.0
# 890        32.0  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# mode method

# %%
df['embarked'].isnull().sum()
# Out:
# np.int64(2)

# %%
mode_value =  df[df['embarked'].notna()]['embarked'].mode()[0]

# %%
df['embarked_mode'] = df['embarked'].fillna(mode_value)

# %%
df['embarked_mode']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked_mode, Length: 891, dtype: object

# %%
df['embarked_mode'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['deck'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: deck, Length: 891, dtype: bool

# %%
df['deck_mean'] = df['deck'].fillna(df['deck'].mode())

# %%
df['deck_mean'].isnull().sum()
# Out:
# np.int64(687)

# %%
new_df = df.drop('deck', axis=1)

# %%
df.drop('deck', axis=1, inplace=True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone  age_mean  age_median  \
# 0    man        True  Southampton    no  False      22.0        22.0
# 1  woman       False    Cherbourg   yes  False      38.0        38.0
# 2  woman       False  Southampton   yes   True      26.0        26.0
# 3  woman       False  Southampton   yes  False      35.0        35.0
# 4    man        True  Southampton    no   True      35.0        35.0
#
#   embarked_mode deck_mean
# 0             S         C
# 1             C         C
# 2             S       NaN
# 3             S         C
# 4             S       NaN

# %%
print(df['survived'].value_counts())
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='survived', data=df)
plt.show()

# %%
majority = df[df.survived == 0]
minority = df[df.survived == 1]


minority_upsampled = resample(
    minority,
    replace = True,
    n_samples=len(majority),
    random_state = 42

)

# %%
df_balanced = pd.concat([majority, minority_upsampled])

print(df_balanced['survived'].value_counts())
# Out:
# survived
# 0    549
# 1    549
# Name: count, dtype: int64

# %%
majority = df[df.survived == 0]
minority = df[df.survived == 1]


majority_upsampled = resample(
    minority,
    replace = False,
    n_samples=len(minority),
    random_state = 42

)

# %%
df_balanced = pd.concat([minority, majority_upsampled])

# %%
print(df_balanced['survived'].value_counts())
# Out:
# survived
# 1    684
# Name: count, dtype: int64
